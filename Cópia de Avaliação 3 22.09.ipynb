# %% [markdown]
# Coloque seu nome aqui:GUSTAVO VIEIRA LIMA

# %% [markdown]
# **Atividade Avaliativa **
#
# Enunciado:
#
# Crie um programa em Python para avaliar uma competição de bandas de música. O programa deve:
#
# Perguntar a quantidade de bandas participantes (mínimo 3).
#
# Perguntar o nome de cada banda.
#
# Para cada banda, receber as notas de 5 jurados (valores de 0 a 10).
#
# Calcular a média das notas de cada banda e armazenar o resultado em um dicionário, onde a chave será o nome da banda e o valor será a média das notas.
#
# Ao final, mostrar:
#
# A média de cada banda.
#
# O nome da banda vencedora (a que tiver maior média).

# %%
int i
def main():

    while True:
        try:
            num_bandas = int(input("Quantas bandas estão participando? (mínimo 3): "))
            if num_bandas >= 3:
                break
            else:
                print("O número de bandas deve ser no mínimo 3.")
        except ValueError:
            
            print("Por favor, insira um número válido.")

    medias_bandas = {}

    for _ in range(num_bandas):
        nome_banda = input("Qual é o nome da banda? ")

        notas = []
        for i in range(5):
            while True:
                try:
                    nota = float(input(f"Digite a nota do jurado {i+1} para a banda {nome_banda}: "))
                    if 0 <= nota <= 10:
                        notas.append(nota)
                        break
                    else:
                        print("A nota deve estar entre 0 e 10.")
                except ValueError:
                    print("Por favor, insira uma nota válida.")

      
        media = sum(notas) / len(notas)
        medias_bandas[nome_banda] = media


    print("\nMédias das bandas:")
    for banda, media in medias_bandas.items():
        print(f"{banda}: {media:.2f}")

    banda_vencedora = max(medias_bandas, key=medias_bandas.get)
    print(f"\nA banda vencedora é {banda_vencedora} com a média {medias_bandas[banda_vencedora]:.2f}!")

if __name__ == "__main__":
    main()
# Out:
#   File <tokenize>:17
#     for i in range
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Enunciado:
#
# Crie um programa que conte quantas vezes cada palavra aparece em uma frase.
#
# Pedir ao usuário para digitar uma frase
#
# Imprimir a palavra e quantas vezes ela aparece

# %%
# Digite sua resposta

def contar_palavras():
    frase = input("Digite uma frase: ")
    palavras = frase.split()
    contagem = {}

    for palavra in palavras:
        contagem[palavra] = contagem.get(palavra, 0) + 1

    for palavra, quantidade in contagem.items():
        print(f"{palavra}: {quantidade}")

if __name__ == "__main__":
    contar_palavras()

# %% [markdown]
# Enunciado:
#
# Crie um programa em python que imprima números pares
#
# Pedir o usuário para digitar uma lista com mínimo 10 números
#
# Criar uma nova somente com numeros pares
#
# Imprimir números pares

# %%
# Digite sua resposta

def filtrar_pares():
    numeros = list(map(int, input("Digite uma lista com pelo menos 10 números separados por espaço: ").split()))
    pares = [num for num in numeros if num % 2 == 0]
    print("Números pares:", pares)

if __name__ == "__main__":
    filtrar_pares()
